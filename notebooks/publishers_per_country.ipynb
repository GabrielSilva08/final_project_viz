# %%
import pandas as pd

# %%
df = pd.read_csv("publisher_info_viz_final_project.csv")

# %%
publisher_summary = df["HQ country"].value_counts().reset_index()
publisher_summary.columns = ["country", "count"]

# %%
publisher_summary
# Out:
#            country  count
# 0    United States     83
# 1   United Kingdom     32
# 2            Japan     20
# 3           Sweden     16
# 4            China     16
# 5           Canada     16
# 6          Germany     11
# 7           France      9
# 8   Czech Republic      9
# 9           Poland      7
# 10     South Korea      4
# 11     New Zealand      4
# 12           Italy      3
# 13     Netherlands      3
# 14          Cyprus      3
# 15         Finland      3
# 16         Croatia      2
# 17         Ukraine      2
# 18         Denmark      2
# 19       Australia      2
# 20       ed States      1
# 21         Belgium      1
# 22         Ireland      1
# 23         Austria      1
# 24          Turkey      1
# 25         Estonia      1
# 26          Russia      1
# 27          Norway      1
# 28     Switzerland      1
# 29       Singapore      1
# 30         Hungary      1
# 31        Slovenia      1
# 32       Hong Kong      1

# %%
publisher_summary.to_dict(orient="records")
# Out:
# [{'country': 'United States', 'count': 83},
#  {'country': 'United Kingdom', 'count': 32},
#  {'country': 'Japan', 'count': 20},
#  {'country': 'Sweden', 'count': 16},
#  {'country': 'China', 'count': 16},
#  {'country': 'Canada', 'count': 16},
#  {'country': 'Germany', 'count': 11},
#  {'country': 'France', 'count': 9},
#  {'country': 'Czech Republic', 'count': 9},
#  {'country': 'Poland', 'count': 7},
#  {'country': 'South Korea', 'count': 4},
#  {'country': 'New Zealand', 'count': 4},
#  {'country': 'Italy', 'count': 3},
#  {'country': 'Netherlands', 'count': 3},
#  {'country': 'Cyprus', 'count': 3},
#  {'country': 'Finland', 'count': 3},
#  {'country': 'Croatia', 'count': 2},
#  {'country': 'Ukraine', 'count': 2},
#  {'country': 'Denmark', 'count': 2},
#  {'country': 'Australia', 'count': 2},
#  {'country': 'ed States', 'count': 1},
#  {'country': 'Belgium', 'count': 1},
#  {'country': 'Ireland', 'count': 1},
#  {'country': 'Austria', 'count': 1},
# ...
